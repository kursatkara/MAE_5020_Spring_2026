# %% [markdown]
# <a href="https://colab.research.google.com/github/kursatkara/MAE_5020_Spring_2026/blob/master/03_4_3_PCA_bearings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np



# https://www.kaggle.com/datasets/vinayak123tyagi/bearing-dataset
# https://github.com/jeffprosise/Machine-Learning/blob/master/Anomaly%20Detection%20(PCA).ipynb
file = "https://raw.githubusercontent.com/jeffprosise/Machine-Learning/refs/heads/master/Data/bearings.csv"

# Read the CSV into a pandas DataFrame, using the first column as a DateTime index
df = pd.read_csv(file, index_col=0, parse_dates=[0])

# Convert the DataFrame to a NumPy array
da = df.to_numpy()

data_array = da[:700,:]

print("Data shape:", data_array.shape)
print("First 5 rows as a NumPy array:\n", data_array)
# Out:
# Data shape: (700, 4)
# First 5 rows as a NumPy array:
#  [[0.05833288 0.07183163 0.08324191 0.04306656]
#  [0.05899521 0.07400571 0.08443542 0.04454104]
#  [0.06023644 0.07422662 0.08392607 0.04444309]
#  ...
#  [0.08279042 0.0744365  0.07613658 0.04534352]
#  [0.08143376 0.0743467  0.07565369 0.04516544]
#  [0.08377997 0.07601235 0.0772672  0.046647  ]]

# %%
# Plot data_array
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(data_array)
plt.xlabel("Time")
plt.ylabel("Values")
plt.title("Plot of data_array")
plt.grid(True)
plt.show()

# %%
# 1) Do the SVD,
# 2) Plot the singular values and cumulative sum of singular values.

# %%
# Plot the first principal component using a scatter plot
# Color the first 500 entries with Green and the rest with Red

# %%
# Plot the second principal component using a scatter plot
# Color the first 500 entries with Green and the rest with Red

# %%
# Plot the third principal component using a scatter plot
# Color the first 500 entries with Green and the rest with Red

# %%
# Plot the fourth principal component using a scatter plot
# Color the first 500 entries with Green and the rest with Red

# %%
# Plot the followings:
# VT[0,:] @ data_array[:,:].T
# VT[1,:] @ data_array[:,:].T
# VT[2,:] @ data_array[:,:].T
# VT[3,:] @ data_array[:,:].T

# %%
# Plot the first PC vs the second PC using a scatter plot
# Color the first 500 entries with Green and the rest with Red

# %%
# Plot the three PCs using a 3D scatter plot
# Color the first 500 entries with Green and the rest with Red
